# %% [markdown]
# # 🚗 Used Car Price Dataset: A dataset for predicting used car price 📊

# %% [markdown]
# Dive into the world of used cars with our dataset, perfect for predicting prices. It's a carefully selected set of data that car enthusiasts, analysts, and data scientists will find valuable. Whether you're curious or looking to analyze, this dataset is your guide to understanding the dynamics of how used cars are valued.

# %%
path = "C:\\Users\\91983\\Downloads\\ML projects\\datasets\\Linier regression\\used_cars_datacard..txt"
with open(path,"r") as file:
    discription = file.read()
print(discription)
# Out:
# Dataset Description:
# 1552 Rows, 15 Columns
#
# Attributes:
#
# car_name
# registration_year
# insurance_validity
# fuel_type
# seats
# kms_driven
# ownership
# transmission
# manufacturing_year
# mileage(kmpl)
# engine(cc)
# max_power(bhp)
# torque(Nm)
# price(in lakhs)
# Steps you can do:
# 1. Data Preprocessing
# 2. Data Visualization
# 3. Explarotary Data Analysis
# 4. Feature Selection and Transformation
# 5. Train-Test-Split
# 6. Model Creation (eg: Multiple Linear Regression)
# 7. Model Prediction

# %% [markdown]
# # Basic library

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Import dataset

# %%
pd.read_csv('Used Car Dataset.csv')
cars=pd.read_csv('Used Car Dataset.csv')
cars
# Out:
#       Unnamed: 0                                           car_name  \
# 0              0                    2017 Mercedes-Benz S-Class S400
# 1              1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2              2                       2018 BMW X1 sDrive 20d xLine
# 3              3                           2019 Kia Seltos GTX Plus
# 4              4                    2019 Skoda Superb LK 1.8 TSI AT
# ...          ...                                                ...
# 1548        1548           2020 Hyundai Creta SX Opt Diesel AT BSVI
# 1549        1549                 2022 Renault KWID 1.0 RXL Opt BSVI
# 1550        1550                           2017 Honda WR-V i-VTEC S
# 1551        1551           2018 Volkswagen Polo 1.0 MPI Comfortline
# 1552        1552                        2018 Maruti Swift Dzire VXI
#
#      registration_year     insurance_validity fuel_type  seats  kms_driven  \
# ...

# %%
cars.columns
# Out:
# Index(['Unnamed: 0', 'car_name', 'registration_year', 'insurance_validity',
#        'fuel_type', 'seats', 'kms_driven', 'ownsership', 'transmission',
#        'manufacturing_year', 'mileage(kmpl)', 'engine(cc)', 'max_power(bhp)',
#        'torque(Nm)', 'price(in lakhs)'],
#       dtype='object')

# %% [markdown]
# # General inferences from the dataset

# %% [raw]
# 1)Here, 'Unnamed: 0', 'registration_year' not required so we need to drop it.
# 2)In the 'car_name' column, car name and brand both are merged so we need to seperate car name and brand name
# 3)'insurance_validity','seats', 'ownsership',', transmission','manufacturing_year' columns has wrong values so we need to fix them
# 4)'insurance_validity', 'fuel_type','ownsership',', transmission',  are categorical data so we need to encode them

# %%
cars.head(5)
# Out:
#    Unnamed: 0                                           car_name  \
# 0           0                    2017 Mercedes-Benz S-Class S400
# 1           1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2           2                       2018 BMW X1 sDrive 20d xLine
# 3           3                           2019 Kia Seltos GTX Plus
# 4           4                    2019 Skoda Superb LK 1.8 TSI AT
#
#   registration_year insurance_validity fuel_type  seats  kms_driven  \
# 0            Jul-17      Comprehensive    Petrol      5       56000
# 1            Jan-21      Comprehensive    Petrol      5       30615
# 2            Sep-18      Comprehensive    Diesel      5       24000
# 3            Dec-19      Comprehensive    Petrol      5       18378
# 4            Aug-19      Comprehensive    Petrol      5       44900
#
#     ownsership transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# 0  First Owner    Automatic               2017           7.81      2996.0
# ...

# %% [markdown]
# # Data Preprocessing

# %% [raw]
# Operations need to perform
# 1) missing value treatment
# 2) Wrong value treatment
# 3) Outliner treatment
# 4) Remove duplicate values
# 5) Encode object variable

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1553 entries, 0 to 1552
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1553 non-null   int64
#  1   car_name            1553 non-null   object
#  2   registration_year   1553 non-null   object
#  3   insurance_validity  1553 non-null   object
#  4   fuel_type           1553 non-null   object
#  5   seats               1553 non-null   int64
#  6   kms_driven          1553 non-null   int64
#  7   ownsership          1553 non-null   object
#  8   transmission        1553 non-null   object
#  9   manufacturing_year  1553 non-null   object
#  10  mileage(kmpl)       1550 non-null   float64
#  11  engine(cc)          1550 non-null   float64
#  12  max_power(bhp)      1550 non-null   float64
#  13  torque(Nm)          1549 non-null   float64
#  14  price(in lakhs)     1553 non-null   float64
# ...

# %%
cars.shape
# Out:
# (1553, 15)

# %%
cars=cars.drop(['Unnamed: 0'],axis=1)  ## not required so I dropped it

# %%
print("Number of duplicate rows:",cars.duplicated().sum())    ## Removing duplicated rows
cars = cars.drop_duplicates()
print("After droping duplicates, number of duplicate rows present in dataset:",cars.duplicated().sum())
# Out:
# Number of duplicate rows: 420
# After droping duplicates, number of duplicate rows present in dataset: 0

# %%
cars.shape
# Out:
# (1133, 14)

# %%
cars.columns
# Out:
# Index(['car_name', 'registration_year', 'insurance_validity', 'fuel_type',
#        'seats', 'kms_driven', 'ownsership', 'transmission',
#        'manufacturing_year', 'mileage(kmpl)', 'engine(cc)', 'max_power(bhp)',
#        'torque(Nm)', 'price(in lakhs)'],
#       dtype='object')

# %%
# registration_year is not required so I dropped them 
cars=cars.drop(['registration_year'],axis=1)

# %%
cars.columns
# Out:
# Index(['car_name', 'insurance_validity', 'fuel_type', 'seats', 'kms_driven',
#        'ownsership', 'transmission', 'manufacturing_year', 'mileage(kmpl)',
#        'engine(cc)', 'max_power(bhp)', 'torque(Nm)', 'price(in lakhs)'],
#       dtype='object')

# %%
cars.isnull().sum()   ## Checking for null values
# Out:
# car_name              0
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# ownsership            0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         2
# engine(cc)            2
# max_power(bhp)        2
# torque(Nm)            3
# price(in lakhs)       0
# dtype: int64

# %%
cars.isnull().sum()/len(cars)*100     ## Checking percentage of null values 
                                    ## Here few amount of null values present so we need to impute rather dropping it
# Out:
# car_name              0.000000
# insurance_validity    0.000000
# fuel_type             0.000000
# seats                 0.000000
# kms_driven            0.000000
# ownsership            0.000000
# transmission          0.000000
# manufacturing_year    0.000000
# mileage(kmpl)         0.176523
# engine(cc)            0.176523
# max_power(bhp)        0.176523
# torque(Nm)            0.264784
# price(in lakhs)       0.000000
# dtype: float64

# %% [markdown]
# Here in the dataset 'mileage(kmpl)', 'engine(cc)', 'max_power(bhp)', 'torque(Nm)' has missing values so we need to impute those missing values with median/mean/mode. Here all the values are numerical so I use median to impute the missing values

# %%
cars['mileage(kmpl)']=cars['mileage(kmpl)'].fillna(cars['mileage(kmpl)'].median())

cars['max_power(bhp)']=cars['max_power(bhp)'].fillna(cars['max_power(bhp)'].median())

cars['engine(cc)']=cars['engine(cc)'].fillna(cars['engine(cc)'].median())

cars['torque(Nm)']=cars['torque(Nm)'].fillna(cars['torque(Nm)'].median())

# %%
cars.isnull().sum()/len(cars)*100
# Out:
# car_name              0.0
# insurance_validity    0.0
# fuel_type             0.0
# seats                 0.0
# kms_driven            0.0
# ownsership            0.0
# transmission          0.0
# manufacturing_year    0.0
# mileage(kmpl)         0.0
# engine(cc)            0.0
# max_power(bhp)        0.0
# torque(Nm)            0.0
# price(in lakhs)       0.0
# dtype: float64

# %%
cars['car_name']     ## We need to split the car name from the brand name
# Out:
# 0                         2017 Mercedes-Benz S-Class S400
# 1       2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2                            2018 BMW X1 sDrive 20d xLine
# 3                                2019 Kia Seltos GTX Plus
# 4                         2019 Skoda Superb LK 1.8 TSI AT
#                               ...
# 1548             2020 Hyundai Creta SX Opt Diesel AT BSVI
# 1549                   2022 Renault KWID 1.0 RXL Opt BSVI
# 1550                             2017 Honda WR-V i-VTEC S
# 1551             2018 Volkswagen Polo 1.0 MPI Comfortline
# 1552                          2018 Maruti Swift Dzire VXI
# Name: car_name, Length: 1133, dtype: object

# %%
#Split model_name and brand_name from car_name then drop car_name column

cars['car_model_name']=cars['car_name'].str.split().str[2:].str.join(' ')
cars['car_brand_name']=cars['car_name'].str.split().str[1:2].str.join(' ')

# %%
cars.head()
# Out:
#                                             car_name insurance_validity  \
# 0                    2017 Mercedes-Benz S-Class S400      Comprehensive
# 1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI      Comprehensive
# 2                       2018 BMW X1 sDrive 20d xLine      Comprehensive
# 3                           2019 Kia Seltos GTX Plus      Comprehensive
# 4                    2019 Skoda Superb LK 1.8 TSI AT      Comprehensive
#
#   fuel_type  seats  kms_driven   ownsership transmission manufacturing_year  \
# 0    Petrol      5       56000  First Owner    Automatic               2017
# 1    Petrol      5       30615  First Owner    Automatic               2020
# 2    Diesel      5       24000  First Owner    Automatic               2018
# 3    Petrol      5       18378  First Owner       Manual               2019
# 4    Petrol      5       44900  First Owner    Automatic               2019
#
# ...

# %%
#After spliting model and brand name drop car_name and car_model_name col
cars=cars.drop(['car_name'],axis=1)
cars=cars.drop(['car_model_name'],axis=1)

# %%
 cars.head()
# Out:
#   insurance_validity fuel_type  seats  kms_driven   ownsership transmission  \
# 0      Comprehensive    Petrol      5       56000  First Owner    Automatic
# 1      Comprehensive    Petrol      5       30615  First Owner    Automatic
# 2      Comprehensive    Diesel      5       24000  First Owner    Automatic
# 3      Comprehensive    Petrol      5       18378  First Owner       Manual
# 4      Comprehensive    Petrol      5       44900  First Owner    Automatic
#
#   manufacturing_year  mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  \
# 0               2017           7.81      2996.0          2996.0       333.0
# 1               2020          17.40       999.0           999.0      9863.0
# 2               2018          20.68      1995.0          1995.0       188.0
# 3               2019          16.50      1353.0          1353.0     13808.0
# 4               2019          14.67      1798.0          1798.0     17746.0
#
#    price(in lakhs) car_brand_name
# ...

# %%
cars.describe(include='all')
# Out:
#        insurance_validity fuel_type         seats     kms_driven   ownsership  \
# count                1133      1133   1133.000000    1133.000000         1133
# unique                  6         4           NaN            NaN           22
# top         Comprehensive    Petrol           NaN            NaN  First Owner
# freq                  790       751           NaN            NaN          922
# mean                  NaN       NaN     64.323036   53115.190644          NaN
# std                   NaN       NaN   1990.335133   43091.691905          NaN
# min                   NaN       NaN      4.000000     620.000000          NaN
# 25%                   NaN       NaN      5.000000   30000.000000          NaN
# 50%                   NaN       NaN      5.000000   49000.000000          NaN
# 75%                   NaN       NaN      5.000000   70000.000000          NaN
# max                   NaN       NaN  67000.000000  810000.000000          NaN
#
# ...

# %%
cars.columns
# Out:
# Index(['insurance_validity', 'fuel_type', 'seats', 'kms_driven', 'ownsership',
#        'transmission', 'manufacturing_year', 'mileage(kmpl)', 'engine(cc)',
#        'max_power(bhp)', 'torque(Nm)', 'price(in lakhs)', 'car_brand_name'],
#       dtype='object')

# %% [markdown]
# ### fixing ''insurance_validity'' column

# %%
cars['insurance_validity'].value_counts()
# Out:
# Comprehensive            790
# Third Party insurance    233
# Third Party               56
# Zero Dep                  52
# Petrol                     1
# Not Available              1
# Name: insurance_validity, dtype: int64

# %% [markdown]
# Here we see that 'petrol' is wrong value so we need to fix this

# %%
cars['insurance_validity'] = cars['insurance_validity'].replace('Third Party','Third Party insurance')

# %%
# Convert 'Petrol' to NaN
cars['insurance_validity'] = cars['insurance_validity'].replace(['Petrol'], np.nan)
# Calculate the mode of the 'Petrol' column
mo_= cars['insurance_validity'].mode()[0]

# Replace NaN values with the mode
cars['insurance_validity'].fillna(mo_, inplace=True)

# %%
cars['insurance_validity'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ### Fixing 'fuel_type'

# %%
cars['fuel_type'].value_counts()
# Out:
# Petrol     751
# Diesel     364
# CNG         17
# 5 Seats      1
# Name: fuel_type, dtype: int64

# %% [markdown]
# Here '5 seats' is a wrong value so we need to fix this

# %%
# Convert '5 Seats' to NaN
cars['fuel_type'] = cars['fuel_type'].replace(['5 Seats'], np.nan)
# Calculate the mode of the 'Petrol' column
mo_= cars['fuel_type'].mode()[0]

# Replace NaN values with the mode
cars['fuel_type'].fillna(mo_, inplace=True)

# %%
cars['fuel_type'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ### Fixing ''seats''

# %%
cars['seats'].value_counts()
# Out:
# 5        996
# 7        108
# 4         15
# 6         11
# 8          2
# 67000      1
# Name: seats, dtype: int64

# %%
# Convert '67000' to NaN
cars['seats'] = cars['seats'].replace([67000], np.nan)

# %%
cars['seats'].isnull().sum()
# Out:
# 1

# %%
cars['seats']=cars['seats'].fillna(cars['seats'].median())

# %%
cars['seats'].value_counts()
# Out:
# 5.0    997
# 7.0    108
# 4.0     15
# 6.0     11
# 8.0      2
# Name: seats, dtype: int64

# %%
cars['seats'] = cars['seats'].astype('int64')

# %%
cars['seats'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ### Fixing ''km_driven''

# %%
cars['kms_driven'].value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### fixing ownership

# %%
cars.rename(columns={'ownsership':'Ownership'}, inplace=True)

# %%
cars['Ownership'].value_counts()
# Out:
# First Owner     922
# Second Owner    167
# Third Owner      18
# 1995 cc           5
# 998 cc            2
# 999 cc            2
# 1498 cc           2
# Fifth Owner       1
# 2999 cc           1
# 1984 cc           1
# 1197 cc           1
# 1248 cc           1
# 1199 cc           1
# 1996 cc           1
# 2013              1
# 1950 cc           1
# 1497 cc           1
# 1998 cc           1
# 1451 cc           1
# 1461 cc           1
# 2993 cc           1
# 1968 cc           1
# Name: Ownership, dtype: int64

# %%
cars['Ownership'] = cars['Ownership'].replace(['1995 cc','1498 cc','1498 cc','999 cc','1497 cc','1451 cc','998 cc','2013','1461 cc','2993 cc','1998 cc','1996 cc','1950 cc','1199 cc','1248 cc','1197 cc','1984 cc','2999 cc','1968 cc'], np.nan)
# Calculate the mode of the 'ownsership' column
mode_ownsership= cars['Ownership'].mode()[0]

# Replace NaN values with the mode
cars['Ownership'].fillna(mode_ownsership, inplace=True)

# %%
cars['Ownership'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ### fixing transmisson

# %%
cars["transmission"].value_counts()
# Out:
# Manual                 646
# Automatic              462
# 2017                     8
# 2014                     3
# 2023                     2
# 2021                     2
# 2011                     2
# 2022                     2
# 2018                     2
# 2020                     1
# Power Windows Front      1
# 2015                     1
# 2016                     1
# Name: transmission, dtype: int64

# %%
cars['transmission'] = cars['transmission'].replace(['Power Windows Front','2017','2014','2011','2023','2020','2021','2022','2023','2018','2015','2016'])
mode_ownsership= cars['transmission'].mode()[0]

# Replace NaN values with the mode
cars['transmission'].fillna(mode_ownsership, inplace=True)

# %%
cars["transmission"].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### Fixing "manufacturing_year"

# %%
cars["manufacturing_year"].value_counts()
# Out:
# 2018                   172
# 2017                   134
# 2019                   133
# 2016                   101
# 2015                    98
# 2020                    94
# 2021                    88
# 2014                    79
# 2022                    66
# 2013                    40
# 2012                    35
# Power Steering          23
# 2023                    22
# 2011                    21
# 2010                    15
# 2009                     9
# Power Windows Front      1
# Air Conditioner          1
# 2007                     1
# Name: manufacturing_year, dtype: int64

# %%
cars['manufacturing_year'] = cars['manufacturing_year'].replace(['Power Steering','Power Windows Front','Air Conditioner'])
mode_ownsership= cars['manufacturing_year'].mode()[0]

# Replace NaN values with the mode
cars['transmission'].fillna(mode_ownsership, inplace=True)

# %%
pd.to_numeric(cars['manufacturing_year'])
# Out:
# 0       2017
# 1       2020
# 2       2018
# 3       2019
# 4       2019
#         ...
# 1548    2020
# 1549    2020
# 1550    2017
# 1551    2018
# 1552    2018
# Name: manufacturing_year, Length: 1133, dtype: int64

# %%
cars["manufacturing_year"].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
cars["manufacturing_year"]=pd.to_numeric(cars["manufacturing_year"])

# %%
cars['car_brand_name'].value_counts().head(20).plot(kind='bar')
plt.show()

# %% [markdown]
# lable encoding: insurance_validity, fuel_type, ownsership, transmission, car_model_name, car_brand_name

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1133 entries, 0 to 1552
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   insurance_validity  1133 non-null   object
#  1   fuel_type           1133 non-null   object
#  2   seats               1133 non-null   int64
#  3   kms_driven          1133 non-null   int64
#  4   Ownership           1133 non-null   object
#  5   transmission        1133 non-null   object
#  6   manufacturing_year  1133 non-null   int64
#  7   mileage(kmpl)       1133 non-null   float64
#  8   engine(cc)          1133 non-null   float64
#  9   max_power(bhp)      1133 non-null   float64
#  10  torque(Nm)          1133 non-null   float64
#  11  price(in lakhs)     1133 non-null   float64
#  12  car_brand_name      1133 non-null   object
# dtypes: float64(5), int64(3), object(5)
# memory usage: 123.9+ KB

# %% [raw]
# We need to encode Object variables
# insurance_validity
# fuel_type
# Ownership
# transmission
# car_brand_name
# Here,I used label encoder to encode all the object variables

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

cars['insurance_validity'] = label.fit_transform(cars['insurance_validity'])

cars['fuel_type'] = label.fit_transform(cars['fuel_type'])

cars['Ownership'] = label.fit_transform(cars['Ownership'])

cars['transmission'] = label.fit_transform(cars['transmission'])

cars['car_brand_name'] = label.fit_transform(cars['car_brand_name'])

cars['seats'] = label.fit_transform(cars['seats'])

# %%
#Dtype: manufacturing_year

# %%
cars['manufacturing_year']=cars['manufacturing_year'].astype('int64')

# %%
cars.isnull().sum()
# Out:
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# Ownership             0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         0
# engine(cc)            0
# max_power(bhp)        0
# torque(Nm)            0
# price(in lakhs)       0
# car_brand_name        0
# dtype: int64

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1133 entries, 0 to 1552
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   insurance_validity  1133 non-null   int32
#  1   fuel_type           1133 non-null   int32
#  2   seats               1133 non-null   int64
#  3   kms_driven          1133 non-null   int64
#  4   Ownership           1133 non-null   int32
#  5   transmission        1133 non-null   int32
#  6   manufacturing_year  1133 non-null   int64
#  7   mileage(kmpl)       1133 non-null   float64
#  8   engine(cc)          1133 non-null   float64
#  9   max_power(bhp)      1133 non-null   float64
#  10  torque(Nm)          1133 non-null   float64
#  11  price(in lakhs)     1133 non-null   float64
#  12  car_brand_name      1133 non-null   int32
# dtypes: float64(5), int32(5), int64(3)
# memory usage: 101.8 KB

# %%
cars.describe()
# Out:
#        insurance_validity    fuel_type        seats     kms_driven  \
# count         1133.000000  1133.000000  1133.000000    1133.000000
# mean             0.648720     1.648720     1.192410   53115.190644
# std              1.007126     0.508054     0.619226   43091.691905
# min              0.000000     0.000000     0.000000     620.000000
# 25%              0.000000     1.000000     1.000000   30000.000000
# 50%              0.000000     2.000000     1.000000   49000.000000
# 75%              2.000000     2.000000     1.000000   70000.000000
# max              3.000000     2.000000     4.000000  810000.000000
#
#          Ownership  transmission  manufacturing_year  mileage(kmpl)  \
# count  1133.000000   1133.000000         1133.000000    1133.000000
# mean      1.178288      0.586937         2017.330097     220.698906
# std       0.424499      0.492601            3.027632     556.808263
# min       0.000000      0.000000         2007.000000       7.810000
# ...

# %%
cars.head()
# Out:
#    insurance_validity  fuel_type  seats  kms_driven  Ownership  transmission  \
# 0                   0          2      1       56000          1             0
# 1                   0          2      1       30615          1             0
# 2                   0          1      1       24000          1             0
# 3                   0          2      1       18378          1             1
# 4                   0          2      1       44900          1             0
#
#    manufacturing_year  mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  \
# 0                2017           7.81      2996.0          2996.0       333.0
# 1                2020          17.40       999.0           999.0      9863.0
# 2                2018          20.68      1995.0          1995.0       188.0
# 3                2019          16.50      1353.0          1353.0     13808.0
# 4                2019          14.67      1798.0          1798.0     17746.0
#
#    price(in lakhs)  car_brand_name
# ...

# %%
def boxplots(col):                              ## Checking for outliers 
    sns.boxplot(cars[col])
    plt.show()
for i in list(cars.select_dtypes(exclude=['object']).columns)[0:]:
    boxplots(i)

# %%
cars.head()
# Out:
#    insurance_validity  fuel_type  seats  kms_driven  Ownership  transmission  \
# 0                   0          2      1       56000          1             0
# 1                   0          2      1       30615          1             0
# 2                   0          1      1       24000          1             0
# 3                   0          2      1       18378          1             1
# 4                   0          2      1       44900          1             0
#
#    manufacturing_year  mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  \
# 0                2017           7.81      2996.0          2996.0       333.0
# 1                2020          17.40       999.0           999.0      9863.0
# 2                2018          20.68      1995.0          1995.0       188.0
# 3                2019          16.50      1353.0          1353.0     13808.0
# 4                2019          14.67      1798.0          1798.0     17746.0
#
#    price(in lakhs)  car_brand_name
# ...

# %% [markdown]
# ### Outlier treatment

# %% [raw]
# Outlier treatment Using Box Plot quantile method
# Outliers found in these variables so we need to fix them.
# kms_driven
# mileage(kmpl)
# engine(cc)
# engine(cc)
# max_power(bhp)
# torque(Nm)
# price(in lakhs)

# %% [markdown]
# Outlier treatment for mileage(kmpl), kms_driven, engine(cc), max_power(bhp), torque(Nm), price(in lakhs),manufacturing_year

# %%
Q1=cars['mileage(kmpl)'].quantile(0.25)    
Q3=cars['mileage(kmpl)'].quantile(0.75)
IQR=Q3-Q1
upper_limit= Q3+ 1.5*IQR
lower_limit= Q3- 1.5*IQR
print('Q1: ',Q1)
print("Q3: ",Q3)
print('IQR: ',IQR)
print('upper limit: ',upper_limit)
print('lower limit: ',lower_limit)

cars['mileage(kmpl)'] = np.where(cars['mileage(kmpl)']>upper_limit, upper_limit,
 np.where(cars['mileage(kmpl)']<lower_limit,lower_limit,
 cars['mileage(kmpl)']))


plt.boxplot(cars['mileage(kmpl)'],vert=False)
plt.title('The distrubution of mileage(kmpl)')
plt.xlabel('mileage(kmpl)')
plt.figure(figsize=(15,5))
plt.show()
# Out:
# Q1:  16.55
# Q3:  22.35
# IQR:  5.800000000000001
# upper limit:  31.050000000000004
# lower limit:  13.65

# %%
Q1=cars['kms_driven'].quantile(0.25)    
Q3=cars['kms_driven'].quantile(0.75)
IQR=Q3-Q1
upper_limit= Q3+ 1.5*IQR
lower_limit= Q3- 1.5*IQR
print('Q1: ',Q1)
print("Q3: ",Q3)
print('IQR: ',IQR)
print('upper limit: ',upper_limit)
print('lower limit: ',lower_limit)


cars['kms_driven'] = np.where(cars['kms_driven']>upper_limit, upper_limit,
 np.where(cars['kms_driven']<lower_limit,lower_limit,
 cars['kms_driven']))



plt.boxplot(cars['kms_driven'],vert=False)
plt.title('The distrubution of kms_driven')
plt.xlabel('kms_driven')
plt.figure(figsize=(15,5))
plt.show()
# Out:
# Q1:  30000.0
# Q3:  70000.0
# IQR:  40000.0
# upper limit:  130000.0
# lower limit:  10000.0

# %%
Q1=cars['engine(cc)'].quantile(0.25)    
Q3=cars['engine(cc)'].quantile(0.75)
IQR=Q3-Q1
upper_limit= Q3+ 1.5*IQR
lower_limit= Q3- 1.5*IQR
print('Q1: ',Q1)
print("Q3: ",Q3)
print('IQR: ',IQR)
print('upper limit: ',upper_limit)
print('lower limit: ',lower_limit)


cars['engine(cc)'] = np.where(cars['engine(cc)']>upper_limit, upper_limit,
 np.where(cars['engine(cc)']<lower_limit,lower_limit,
 cars['engine(cc)']))


plt.boxplot(cars['engine(cc)'],vert=False)
plt.title('The distrubution of engine(cc)')
plt.xlabel('engine(cc)')
plt.figure(figsize=(15,5))
plt.show()
# Out:
# Q1:  1197.0
# Q3:  1991.0
# IQR:  794.0
# upper limit:  3182.0
# lower limit:  800.0

# %%
Q1=cars['max_power(bhp)'].quantile(0.25)    
Q3=cars['max_power(bhp)'].quantile(0.75)
IQR=Q3-Q1
upper_limit= Q3+ 1.5*IQR
lower_limit= Q3- 1.5*IQR
print('Q1: ',Q1)
print("Q3: ",Q3)
print('IQR: ',IQR)
print('upper limit: ',upper_limit)
print('lower limit: ',lower_limit)



cars['max_power(bhp)'] = np.where(cars['max_power(bhp)']>upper_limit, upper_limit,
 np.where(cars['max_power(bhp)']<lower_limit,lower_limit,
 cars['max_power(bhp)']))



plt.boxplot(cars['max_power(bhp)'],vert=False)
plt.title('The distrubution of max_power(bhp)')
plt.xlabel('max_power(bhp)')
plt.figure(figsize=(15,5))
plt.show()
# Out:
# Q1:  1197.0
# Q3:  1991.0
# IQR:  794.0
# upper limit:  3182.0
# lower limit:  800.0

# %%
Q1=cars['torque(Nm)'].quantile(0.25)    
Q3=cars['torque(Nm)'].quantile(0.75)
IQR=Q3-Q1
upper_limit= Q3+ 1.5*IQR
lower_limit= Q3- 1.5*IQR
print('Q1: ',Q1)
print("Q3: ",Q3)
print('IQR: ',IQR)
print('upper limit: ',upper_limit)
print('lower limit: ',lower_limit)


cars['torque(Nm)'] = np.where(cars['torque(Nm)']>upper_limit, upper_limit,
 np.where(cars['torque(Nm)']<lower_limit,lower_limit,
 cars['torque(Nm)']))


plt.boxplot(cars['torque(Nm)'],vert=False)
plt.title('The distrubution of torque(Nm)')
plt.xlabel('torque(Nm)')
plt.figure(figsize=(15,5))
plt.show()
# Out:
# Q1:  430.0
# Q3:  8850.0
# IQR:  8420.0
# upper limit:  21480.0
# lower limit:  -3780.0

# %%
Q1=cars['price(in lakhs)'].quantile(0.25)    
Q3=cars['price(in lakhs)'].quantile(0.75)
IQR=Q3-Q1
upper_limit= Q3+ 1.5*IQR
lower_limit= Q3- 1.5*IQR
print('Q1: ',Q1)
print("Q3: ",Q3)
print('IQR: ',IQR)
print('upper limit: ',upper_limit)
print('lower limit: ',lower_limit)


cars['price(in lakhs)'] = np.where(cars['price(in lakhs)']>upper_limit, upper_limit,
 np.where(cars['price(in lakhs)']<lower_limit,lower_limit,
 cars['price(in lakhs)']))


plt.boxplot(cars['price(in lakhs)'],vert=False)
plt.title('The distrubution of price(in lakhs)')
plt.xlabel('price(in lakhs)')
plt.figure(figsize=(15,5))
plt.show()
# Out:
# Q1:  4.5
# Q3:  14.95
# IQR:  10.45
# upper limit:  30.625
# lower limit:  -0.7249999999999996

# %%
Q1=cars['manufacturing_year'].quantile(0.25)    
Q3=cars['manufacturing_year'].quantile(0.75)
IQR=Q3-Q1
upper_limit= Q3+ 1.5*IQR
lower_limit= Q3- 1.5*IQR
print('Q1: ',Q1)
print("Q3: ",Q3)
print('IQR: ',IQR)
print('upper limit: ',upper_limit)
print('lower limit: ',lower_limit)


cars['manufacturing_year'] = np.where(cars['manufacturing_year']>upper_limit, upper_limit,
 np.where(cars['manufacturing_year']<lower_limit,lower_limit,
 cars['manufacturing_year']))


plt.boxplot(cars['manufacturing_year'],vert=False)
plt.title('The distrubution of manufacturing_year')
plt.xlabel('manufacturing_year')
plt.figure(figsize=(15,5))
plt.show()
# Out:
# Q1:  2015.0
# Q3:  2019.0
# IQR:  4.0
# upper limit:  2025.0
# lower limit:  2013.0

# %%
def boxplots(col):                             ## Checking after removing the outliers
    sns.boxplot(cars[col])
    plt.show()
for i in list(cars.select_dtypes(exclude=['object']).columns)[0:]:
    boxplots(i)

# %%
cars.corr()
# Out:
#                     insurance_validity  fuel_type     seats  kms_driven  \
# insurance_validity            1.000000  -0.041106  0.033400    0.035656
# fuel_type                    -0.041106   1.000000 -0.281981   -0.184371
# seats                         0.033400  -0.281981  1.000000    0.054658
# kms_driven                    0.035656  -0.184371  0.054658    1.000000
# Ownership                     0.092898  -0.082091  0.040776    0.154920
# transmission                 -0.050568   0.136253 -0.109913    0.166641
# manufacturing_year            0.034199  -0.020529  0.077209   -0.537757
# mileage(kmpl)                 0.056808  -0.080404 -0.131599   -0.025340
# engine(cc)                    0.026775  -0.332282  0.277456   -0.028052
# max_power(bhp)                0.026775  -0.332282  0.277456   -0.028052
# torque(Nm)                   -0.008577   0.005280  0.018697   -0.148659
# price(in lakhs)               0.085557  -0.265623  0.209718   -0.256945
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1133 entries, 0 to 1552
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   insurance_validity  1133 non-null   int32
#  1   fuel_type           1133 non-null   int32
#  2   seats               1133 non-null   int64
#  3   kms_driven          1133 non-null   float64
#  4   Ownership           1133 non-null   int32
#  5   transmission        1133 non-null   int32
#  6   manufacturing_year  1133 non-null   float64
#  7   mileage(kmpl)       1133 non-null   float64
#  8   engine(cc)          1133 non-null   float64
#  9   max_power(bhp)      1133 non-null   float64
#  10  torque(Nm)          1133 non-null   float64
#  11  price(in lakhs)     1133 non-null   float64
#  12  car_brand_name      1133 non-null   int32
# dtypes: float64(7), int32(5), int64(1)
# memory usage: 134.1 KB

# %%
sns.heatmap(cars.corr(),annot=True)
plt.figure(figsize=(15,15))
plt.show()

# %%
cars = cars.drop('engine(cc)',axis=1) ## max_power and engine have high correlation so i drop engine(cc)

# %%
sns.heatmap(cars.corr(),annot=True)
plt.figure(figsize=(15,15))
plt.show()

# %%
x=cars.drop('price(in lakhs)',axis=1)          ## Independent variables 
y=cars['price(in lakhs)']  ## Dependent variable

# %%
x
# Out:
#       insurance_validity  fuel_type  seats  kms_driven  Ownership  \
# 0                      0          2      1     56000.0          1
# 1                      0          2      1     30615.0          1
# 2                      0          1      1     24000.0          1
# 3                      0          2      1     18378.0          1
# 4                      0          2      1     44900.0          1
# ...                  ...        ...    ...         ...        ...
# 1548                   0          1      1     35000.0          1
# 1549                   2          2      1     10000.0          1
# 1550                   0          2      1     49000.0          1
# 1551                   0          2      1     40000.0          2
# 1552                   0          2      1     34756.0          1
#
#       transmission  manufacturing_year  mileage(kmpl)  max_power(bhp)  \
# 0                0              2017.0          13.65          2996.0
# ...

# %%
y
# Out:
# 0       30.625
# 1        8.990
# 2       23.750
# 3       13.560
# 4       24.000
#          ...
# 1548    17.410
# 1549     3.980
# 1550     5.850
# 1551     4.750
# 1552     6.100
# Name: price(in lakhs), Length: 1133, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler   
scaler = StandardScaler()
sc_x = scaler.fit_transform(x)
pd.DataFrame(sc_x)
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.644415  0.691727 -0.310863  0.146369 -0.420181 -1.192032 -0.174248
# 1    -0.644415  0.691727 -0.310863 -0.750194 -0.420181 -1.192032  0.922545
# 2    -0.644415 -1.277436 -0.310863 -0.983827 -0.420181 -1.192032  0.191350
# 3    -0.644415  0.691727 -0.310863 -1.182388 -0.420181  0.838904  0.556947
# 4    -0.644415  0.691727 -0.310863 -0.245668 -0.420181 -1.192032  0.556947
# ...        ...       ...       ...       ...       ...       ...       ...
# 1128 -0.644415 -1.277436 -0.310863 -0.595322 -0.420181 -1.192032  0.922545
# 1129  1.342311  0.691727 -0.310863 -1.478288 -0.420181 -1.192032  0.922545
# 1130 -0.644415  0.691727 -0.310863 -0.100861 -0.420181  0.838904 -0.174248
# 1131 -0.644415  0.691727 -0.310863 -0.418729  1.936577  0.838904  0.191350
# 1132 -0.644415  0.691727 -0.310863 -0.603940 -0.420181  0.838904  0.191350
#
#             7         8         9         10
# ...

# %%
## variance_inflation_factor of Independent variables
var = sc_x

from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd

# Assuming sc_x and x are already defined
var = sc_x
vif = pd.DataFrame()
vif["variance_inflation_factor"] = [variance_inflation_factor(var, i) for i in range(var.shape[1])]
vif["features"] = x.columns

# Display the VIF dataframe
vif
# Out:
#     variance_inflation_factor            features
# 0                    1.028741  insurance_validity
# 1                    1.272769           fuel_type
# 2                    1.185637               seats
# 3                    1.515298          kms_driven
# 4                    1.087413           Ownership
# 5                    1.487186        transmission
# 6                    1.697120  manufacturing_year
# 7                    1.334247       mileage(kmpl)
# 8                    1.355521      max_power(bhp)
# 9                    1.211086          torque(Nm)
# 10                   1.051441      car_brand_name

# %% [markdown]
# A variance inflation factor (VIF) is a measure of the amount of multicollinearity in regression analysis. Multicollinearity exists when there is a correlation between multiple independent variables in a multiple regression model. Here all the variables shows low VIF score that represents there is no multicollinearity among the independent variables

# %%
# Splitting the data into train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.20,random_state=101)

# %%
scaler1 = StandardScaler()
x_train = scaler1.fit_transform(x_train)   ## Feature scalling of train and test data
x_test = scaler1.transform(x_test)

# %%
# Building the model with train data
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.coef_)
print('***********'*5)
print(lm.intercept_)
# Out:
# [ 0.49922053 -1.7859381   0.21291346 -1.37404831  0.20523171 -3.31810628
#   1.51325561 -1.30549038  2.34244415  0.59810232 -0.63206454]
# *******************************************************
# 11.012753863134677

# %%
y_pred = lm.predict(x_test)    ## Predicting test value
y_pred
# Out:
# array([ 2.00925252e+01,  4.70501969e+00,  1.42597595e+01,  8.00769354e+00,
#         1.55505244e+01,  2.23564057e+01,  4.52193768e+00,  5.07026715e+00,
#         9.02644414e+00,  9.24493727e+00,  1.72071961e+01,  1.86965086e+01,
#         2.38550865e+00,  1.80579741e+00,  2.42341902e+01,  2.36248233e+01,
#         5.16739175e+00,  4.21900709e+00,  2.07172723e+01,  1.41773926e+01,
#         8.29311763e+00,  1.46634085e+01,  1.49658542e+01,  8.46530003e+00,
#         2.83421437e+00,  1.32308434e+01,  1.82103700e+01,  3.83221679e+00,
#         2.32193081e+01,  5.12190115e+00,  5.61726791e+00,  7.03283630e+00,
#         1.54679482e+00,  2.23394189e+00,  1.58667596e+01,  1.46479389e+01,
#         8.92230008e+00,  1.46572600e+01,  2.39818736e+01,  1.36558658e+01,
#         3.89890226e+00,  1.24784960e+01,  1.87165485e+01,  6.20778465e+00,
#         2.79638528e+01,  2.21855430e+01,  1.61213944e+01,  3.36736950e+00,
# ...

# %%
from sklearn.metrics import r2_score
print("Accuracy: ", r2_score(y_test,y_pred))
# Out:
# Accuracy:  0.4827396773760029

# %%
sns.regplot(x=y_test,y=y_pred, color='red')
plt.show()

# %%
sns.distplot((y_test-y_pred),bins = 50)
plt.show()

# %% [markdown]
# ### OLS method

# %%
from statsmodels.regression.linear_model import OLS
import statsmodels.regression.linear_model as smf

# %%
reg1 = smf.OLS(endog = y_train,exog=x_train).fit()
reg1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:        price(in lakhs)   R-squared (uncentered):                   0.244
# Model:                            OLS   Adj. R-squared (uncentered):              0.234
# Method:                 Least Squares   F-statistic:                              26.20
# Date:                Fri, 09 Feb 2024   Prob (F-statistic):                    1.64e-47
# Time:                        09:09:31   Log-Likelihood:                         -3581.4
# No. Observations:                 906   AIC:                                      7185.
# Df Residuals:                     895   BIC:                                      7238.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
cars=cars.drop(['seats','Ownership','insurance_validity','torque(Nm)','car_brand_name'],axis=1)

# %%
x1=cars.drop('price(in lakhs)',axis=1)
y1=cars['price(in lakhs)']

# %%
x1
# Out:
#       fuel_type  kms_driven  transmission  manufacturing_year  mileage(kmpl)  \
# 0             2     56000.0             0              2017.0          13.65
# 1             2     30615.0             0              2020.0          17.40
# 2             1     24000.0             0              2018.0          20.68
# 3             2     18378.0             1              2019.0          16.50
# 4             2     44900.0             0              2019.0          14.67
# ...         ...         ...           ...                 ...            ...
# 1548          1     35000.0             0              2020.0          31.05
# 1549          2     10000.0             0              2020.0          31.05
# 1550          2     49000.0             1              2017.0          17.50
# 1551          2     40000.0             1              2018.0          18.78
# 1552          2     34756.0             1              2018.0          20.85
#
#       max_power(bhp)
# 0             2996.0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train1,x_test1,y_train1,y_test1 = train_test_split(x1,y1,test_size =0.30,random_state=101)

# %%
from sklearn.preprocessing import StandardScaler
scaler1 = StandardScaler()
x_train1 = scaler1.fit_transform(x_train1)
x_test1 = scaler1.transform(x_test1)

# %%
from sklearn.linear_model import LinearRegression
lm1 = LinearRegression()
lm1.fit(x_train1,y_train1)
# Out:
# LinearRegression()

# %%
print(lm1.coef_)
print('***********'*5)
print(lm1.intercept_)
# Out:
# [-1.74116863 -1.21857799 -3.37071079  1.5483984  -1.29185144  2.47801006]
# *******************************************************
# 10.958726355611597

# %%
y_pred1 = lm1.predict(x_test1)
y_pred1
# Out:
# array([ 2.06736051e+01,  4.09978002e+00,  1.34761668e+01,  7.67154450e+00,
#         1.50775623e+01,  1.95665456e+01,  6.19953787e+00,  6.09984923e+00,
#         7.76129575e+00,  8.62967865e+00,  1.41921028e+01,  1.83754831e+01,
#         1.76081518e+00,  2.87256506e+00,  2.23539953e+01,  2.38796539e+01,
#         5.74806570e+00,  3.64486709e+00,  1.94721216e+01,  1.45073519e+01,
#         9.21716922e+00,  1.55258564e+01,  1.39739301e+01,  9.38290204e+00,
#         3.51356375e+00,  1.37538253e+01,  1.98689016e+01,  5.22332754e+00,
#         2.43745862e+01,  5.32832610e+00,  6.94763153e+00,  5.69229175e+00,
#         7.27596056e-01,  4.05152766e+00,  1.50089665e+01,  1.51053627e+01,
#         8.47927153e+00,  1.34590042e+01,  2.42288950e+01,  1.31793398e+01,
#         4.05032591e+00,  1.25646016e+01,  1.88358032e+01,  4.79584009e+00,
#         2.73277166e+01,  2.11727587e+01,  1.72026826e+01,  3.30848044e+00,
# ...

# %%
from sklearn.metrics import r2_score
print("Accuracy: ", r2_score(y_test1,y_pred1))
# Out:
# Accuracy:  0.5218316212270071

# %%
a = pd.DataFrame(x_train1)
a
# Out:
#             0         1         2         3         4         5
# 0    0.690677 -1.067008 -1.196877  0.196464 -0.188022 -0.638832
# 1    0.690677  0.988070  0.835508 -1.615118  1.999562 -1.217720
# 2    0.690677 -0.518234  0.835508 -0.890485  1.999562 -1.217720
# 3    0.690677  0.382641  0.835508 -0.528169 -0.326264 -0.640287
# 4    0.690677  0.040452 -1.196877  1.283414 -0.251538 -0.637378
# ..        ...       ...       ...       ...       ...       ...
# 788  0.690677 -1.234927  0.835508  0.921097  0.010000 -0.644650
# 789  0.690677  0.463779  0.835508  0.196464 -0.849341 -0.067217
# 790  0.690677 -1.476471  0.835508  1.645730 -0.189890 -0.637378
# 791 -1.315575  0.111006 -1.196877  0.558781 -1.250990  0.454946
# 792 -1.315575  0.534334  0.835508 -0.890485  1.999562 -1.217720
#
# [793 rows x 6 columns]

# %%
reg= smf.OLS(endog = y_train1,exog=x_train1).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:        price(in lakhs)   R-squared (uncentered):                   0.236
# Model:                            OLS   Adj. R-squared (uncentered):              0.230
# Method:                 Least Squares   F-statistic:                              40.50
# Date:                Fri, 09 Feb 2024   Prob (F-statistic):                    4.52e-43
# Time:                        09:09:31   Log-Likelihood:                         -3134.1
# No. Observations:                 793   AIC:                                      6280.
# Df Residuals:                     787   BIC:                                      6308.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=0.3)
ridge.fit(x_train1, y_train1)
print("Ridge Model :", ridge.coef_)
# Out:
# Ridge Model : [-1.74073031 -1.21819893 -3.36978955  1.54837973 -1.29164553  2.47765929]

# %%
y_pred_ridge_train = ridge.predict(x_train1)
y_pred_ridge_test = ridge.predict(x_test1)

# %%
print("Ridge_Train_ACC :", r2_score(y_train1, y_pred_ridge_train))
print()
print("Ridge_Test_ACC :", r2_score(y_test1, y_pred_ridge_test))
# Out:
# Ridge_Train_ACC : 0.559761096879126
#
# Ridge_Test_ACC : 0.521821075761056

# %% [markdown]
# ### Performance metrix

# %%
from sklearn import metrics

# %%
print("MAE :",metrics.mean_absolute_error(y_test1, y_pred1))
# Out:
# MAE : 4.761706791122139

# %%
# Mean Absolute Percent Error
print("MAPE :", metrics.mean_absolute_error(y_test1, y_pred1)/y_test1*100)
# Out:
# MAPE : 30      17.668671
# 957     76.187309
# 293     73.369904
# 1131    52.907853
# 1332    51.477911
#           ...
# 990     58.497626
# 298     15.548430
# 1292    88.179755
# 1041    61.840348
# 1372    15.548430
# Name: price(in lakhs), Length: 340, dtype: float64

# %%
# Mean Squared Error 
print("MSE :", metrics.mean_squared_error(y_test1, y_pred1))
# Out:
# MSE : 43.06087749865543

# %%
# Root Mean Squared Error
print("MSE :", np.sqrt(metrics.mean_squared_error(y_test1, y_pred1)))
# Out:
# MSE : 6.562078748282089

# %% [markdown]
# # Random Forest Regressor model

# %%
from sklearn.ensemble import RandomForestRegressor
rf_regressor = RandomForestRegressor(n_estimators=500)
rf_regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=500)

# %%
# Predict test data
y_pred_train_rf = rf_regressor.predict(x_train)
y_pred_test_rf = rf_regressor.predict(x_test)

# %%
# Evaluate your model
from sklearn.metrics import r2_score
print("Training Accuracy :", r2_score(y_train, y_pred_train_rf))
print()
print("Test Accuracy :", r2_score(y_test, y_pred_test_rf))
# Out:
# Training Accuracy : 0.9723666928316748
#
# Test Accuracy : 0.7955163816048995

# %%
from sklearn.model_selection import cross_val_score
training_accuracy = cross_val_score(rf_regressor, x_train, y_train, cv=10)
print(training_accuracy)

print('**********************'*5)

print(training_accuracy.mean())
# Out:
# [0.90924418 0.77432815 0.70190115 0.74115071 0.76744394 0.82165037
#  0.65764276 0.77647125 0.88037353 0.74803233]
# **************************************************************************************************************
# 0.7778238374857938
